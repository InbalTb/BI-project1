# %%
# !pip install jsonpath_ng
# Out:
# Collecting jsonpath_ng
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting ply (from jsonpath_ng)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)
# Installing collected packages: ply, jsonpath_ng
# Successfully installed jsonpath_ng-1.5.3 ply-3.11

# %%
import os
import json
import numpy as np
import pandas as pd
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %% [markdown]
# ### **Starting ETL Process**

# %% [markdown]
# ### Data

# %%
with open("Amazon_database.json", "r") as file:
    data = json.loads(json.load(file))
    for item in data:
      item["product_parent"]=str(item["product_parent"])
      item["star_rating"]=str(item["star_rating"])
      item["helpful_votes"]=str(item["helpful_votes"])
      item["total_votes"]=str(item["total_votes"])
      item["review_date"]=str(item["review_date"])
      item["customer_id"]=str(item["customer_id"])

data[:10]
# Out:
# [{'customer_id': '1797882',
#   'review_id': 'R3I2DHQBR577SS',
#   'product_id': 'B001ANOOOE',
#   'product_parent': '2102612',
#   'product_title': 'The Naked Bee Vitmin C Moisturizing Sunscreen SPF 30, 5.5 oz (163 ml.)',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'Five Stars',
#   'review_body': 'Love this, excellent sun block!!',
#   'review_date': '1440979200000'},
#  {'customer_id': '18381298',
#   'review_id': 'R1QNE9NQFJC2Y4',
#   'product_id': 'B0016J22EQ',
#   'product_parent': '106393691',
#   'product_title': 'Alba Botanica Sunless Tanning Lotion, 4 Ounce',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'Thank you Alba Bontanica!',
#   'review_body': "The great thing about this cream is that it doesn't smell weird like all those chemical laden ones.  I get a nice healthy un-fake looking tan that isn't orange and it makes my skin soft too.",
#   'review_date': '1440979200000'},
#  {'customer_id': '19242472',
#   'review_id': 'R3LIDG2Q4LJBAO',
#   'product_id': 'B00HU6UQAG',
#   'product_parent': '375449471',
#   'product_title': 'Elysee Infusion Skin Therapy Elixir, 2oz.',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'Five Stars',
#   'review_body': "Great Product, I'm 65 years old and this is all it claims to be!",
#   'review_date': '1440979200000'},
#  {'customer_id': '19551372',
#   'review_id': 'R3KSZHPAEVPEAL',
#   'product_id': 'B002HWS7RM',
#   'product_parent': '255651889',
#   'product_title': 'Diane D722 Color, Perm And Conditioner Processing Caps - 100-Pack - Clear',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'GOOD DEAL!',
#   'review_body': "I use them as shower caps & conditioning caps. I like that they're in bulk. It saves a lot of money.",
#   'review_date': '1440979200000'},
#  {'customer_id': '14802407',
#   'review_id': 'RAI2OIG50KZ43',
#   'product_id': 'B00SM99KWU',
#   'product_parent': '116158747',
#   'product_title': 'Biore UV Aqua Rich Watery Essence SPF50+/PA++++ (pack of 2)',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'this soaks in quick and provides a nice base for makeup',
#   'review_body': "This is my go-to daily sunblock. It leaves no white cast at all and has a clean, pleasant scent. If you're a makeup wearer, this soaks in quick and provides a nice base for makeup. I've been using this brand for over a year. With daily use, this tube will last you a couple months.",
#   'review_date': '1440979200000'},
#  {'customer_id': '2909389',
#   'review_id': 'R1R30FA4RB5P54',
#   'product_id': 'B000NYL1Z6',
#   'product_parent': '166146615',
#   'product_title': 'Murad Clarifying Cleanser',
#   'star_rating': '4',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'Four Stars',
#   'review_body': 'Good',
#   'review_date': '1440979200000'},
#  {'customer_id': '19397215',
#   'review_id': 'R30IJKCGJBGPJH',
#   'product_id': 'B001SYWTFG',
#   'product_parent': '111742328',
#   'product_title': 'CoverGirl Queen Collection Perfect Point Plus Eyeliner Black Onyx 200',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'Good buy',
#   'review_body': 'Great eyeliner, does run just a little bit at corners at times, but overall, it does keep on your eyes all day long.',
#   'review_date': '1440979200000'},
#  {'customer_id': '3195210',
#   'review_id': 'R18GLJJPVQ1OVH',
#   'product_id': 'B005F2EVMQ',
#   'product_parent': '255803087',
#   'product_title': 'Bifesta Mandom Eye Makeup Remover, 145ml',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'Five Stars',
#   'review_body': 'Best makeup remover！',
#   'review_date': '1440979200000'},
#  {'customer_id': '52216383',
#   'review_id': 'R8TVYIJXLYJT0',
#   'product_id': 'B00M1SUW7K',
#   'product_parent': '246816549',
#   'product_title': 'Can You Handlebar All-Natural Secondary Moustache Wax : Extra Strength, Firm Hold',
#   'star_rating': '5',
#   'helpful_votes': '0',
#   'total_votes': '0',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': 'Tame the wild mustache',
#   'review_body': "This is a great product. I'm on my latest stab at a major beard, and I always seem to start growing them during the hottest months. My mustache is going through a particularly awkward phase of growth, and this wax really helps keep it in place, out of the way. I look neater and I can actually eat and drink again without collecting a big mess. If you're going to get this, do yourself a favor and get a good mustache comb.",
#   'review_date': '1440979200000'},
#  {'customer_id': '10278216',
#   'review_id': 'R1CJGF6M3PVHEZ',
#   'product_id': 'B001KYQA1S',
#   'product_parent': '9612905',
#   'product_title': 'Maybelline Great Lash Washable Mascara, Clear [110], 1 ea',
#   'star_rating': '1',
#   'helpful_votes': '0',
#   'total_votes': '2',
#   'vine': 'N',
#   'verified_purchase': 'Y',
#   'review_headline': "but it's like having nothing on them at all",
#   'review_body': "I thought it would darken the lashes even though it's clear, but it's like having nothing on them at all. Sadly I threw it away.",
#   'review_date': '1440979200000'}]

# %% [markdown]
# ###  Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):
    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# ### Transform Operations
# inherithed from Enum - class that automatic enumrate the variables

# %%
class TransformMask(Enum):
    CAPITAL_LETTER = ".strip().upper()"

# %% [markdown]
# ### Database Class - Define Common Properties for Source, Target, Mapping

# %%
columns = data[0].keys()
fact = ['review_id','product_id','review_date','customer_id','vine',
        'star_rating','helpful_votes','total_votes','verified_purchase']
dimProduct= ['product_id', 'product_parent','product_title']
dimReviewInfo= ['review_id', 'review_headline','review_body']

fact_numeric = ['star_rating','helpful_votes','total_votes']
fact_categorial = ['review_id','product_id','review_date','customer_id','vine','verified_purchase']
dimProduct_numeric= ['product_parent']
dimProduct_categorial= ['product_id','product_title']
dimReviewInfo_categorial= ['review_id','review_headline','review_body']
capital = ['vine','verified_purchase','product_id']

# %%
class Database:
    def __init__(self):
        self.db = {
             "source" : [],
             "destination": [],
             "transform" : [],
             "mapping" : []
        }
        self.add_fact_sources()
        self.add_fact_destination()
        self.add_fact_transform()
        self.add_fact_mapping()


    def add_fact_sources(self):
      i = 1
      for column in fact:
          self.add_source(i, column, "str", True)
          i += 1
      for column in dimProduct:
          self.add_source(i, column, "str", True)
          i += 1

      for column in dimReviewInfo:
          self.add_source(i, column, "str", True)
          i += 1

    def add_fact_destination(self):
      i=1
      for column in fact_numeric:
          self.add_destination(i, column, "int", 0, "fact")
          i += 1

      for column in fact_categorial:
          self.add_destination(i, column, "str", "n/a", "fact")
          i += 1

      for column in dimProduct_numeric:
          self.add_destination(i, column, "int", 0, "dimProduct")
          i += 1

      for column in dimProduct_categorial:
          self.add_destination(i, column, "str", "n/a", "dimProduct")
          i += 1

      for column in dimReviewInfo_categorial:
          self.add_destination(i, column, "str", "n/a", "dimReviewInfo")
          i += 1

    def add_fact_transform(self):
      i=1
      for column in capital:
          self.add_transform(i,'CAPITAL_LETTER')
          i += 1

    def add_fact_mapping(self):
      self.add_mapping(1,1,4, "fact")
      self.add_mapping(2,2,5, "fact")
      self.add_mapping(3,3,6, "fact")

      self.add_mapping(4,4,7, "fact")
      self.add_mapping(5,5,8, "fact",1)
      self.add_mapping(6,6,1, "fact")
      self.add_mapping(7,7,2, "fact")
      self.add_mapping(8,8,3, "fact")
      self.add_mapping(9,9,9, "fact",2)
      self.add_mapping(10,2,11, "dimProduct",3)
      self.add_mapping(11,11,10, "dimProduct")
      self.add_mapping(12,12,12, "dimProduct")
      self.add_mapping(13,1,13, "dimReviewInfo")
      self.add_mapping(14,14,14, "dimReviewInfo")
      self.add_mapping(15,15,15, "dimReviewInfo")

    def add_source(self, id, field, ty,is_required):
      new_source = { "id": id,
                    "source_field_name": field,
                   "source_field_mapping": f"$.{field}",
                    "source_field_type": ty, # use python types
                    "is_required":is_required }
      self.db["source"].append(new_source)


    def add_destination(self, id, field, ty, default_value, table):
      new_destination = { "id": id,
                    "destination_field_name": field,
                    "destination_field_mapping": f"$.{field}",
                    "destination_field_type": ty, # use python types
                    "default_value": default_value,
                    "destination_table": table}
      self.db["destination"].append(new_destination)


    def add_transform(self, id, transform_mask):
      new_transform = { "id": id,
                    "transform_mask": transform_mask,}
      self.db["transform"].append(new_transform)

    def add_mapping(self, id, mapping_source, mapping_destination, table, mapping_transform = None):
      new_mapping = {"id": id,
                    "mapping_source": mapping_source,
                    "mapping_destination": mapping_destination,
                    "destination_table": table,
                    "mapping_transform":mapping_transform
                     }
      self.db["mapping"].append(new_mapping)

    @property
    def get_data_source_target_mapping(self):
      return self.db

# %% [markdown]
# ### Source class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# ### Target class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Transform Class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Mapping class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# ### Format Class - JSON
#
# Search the source data value inside a JSON file

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# ### Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}
        self.to_table= {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")
            mapping_destination_table = mappings.get("destination_table")


            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))

                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                self.to_table[destination_field_name]= mapping_destination_table

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed, self.to_table

# %%
transformed_data = []

for item in data[:10000]:
    helper = STTM(input_json=item)
    response, mapping = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
print(mapping)
# Out:
# {'review_id': 'R3I2DHQBR577SS', 'product_id': 'B001ANOOOE', 'review_date': '1440979200000', 'customer_id': '1797882', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 2102612, 'product_title': 'The Naked Bee Vitmin C Moisturizing Sunscreen SPF 30, 5.5 oz (163 ml.)', 'review_headline': 'Five Stars', 'review_body': 'Love this, excellent sun block!!'}
# {'review_id': 'R1QNE9NQFJC2Y4', 'product_id': 'B0016J22EQ', 'review_date': '1440979200000', 'customer_id': '18381298', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 106393691, 'product_title': 'Alba Botanica Sunless Tanning Lotion, 4 Ounce', 'review_headline': 'Thank you Alba Bontanica!', 'review_body': "The great thing about this cream is that it doesn't smell weird like all those chemical laden ones.  I get a nice healthy un-fake looking tan that isn't orange and it makes my skin soft too."}
# {'review_id': 'R3LIDG2Q4LJBAO', 'product_id': 'B00HU6UQAG', 'review_date': '1440979200000', 'customer_id': '19242472', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 375449471, 'product_title': 'Elysee Infusion Skin Therapy Elixir, 2oz.', 'review_headline': 'Five Stars', 'review_body': "Great Product, I'm 65 years old and this is all it claims to be!"}
# {'review_id': 'R3KSZHPAEVPEAL', 'product_id': 'B002HWS7RM', 'review_date': '1440979200000', 'customer_id': '19551372', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 255651889, 'product_title': 'Diane D722 Color, Perm And Conditioner Processing Caps - 100-Pack - Clear', 'review_headline': 'GOOD DEAL!', 'review_body': "I use them as shower caps & conditioning caps. I like that they're in bulk. It saves a lot of money."}
# {'review_id': 'RAI2OIG50KZ43', 'product_id': 'B00SM99KWU', 'review_date': '1440979200000', 'customer_id': '14802407', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 116158747, 'product_title': 'Biore UV Aqua Rich Watery Essence SPF50+/PA++++ (pack of 2)', 'review_headline': 'this soaks in quick and provides a nice base for makeup', 'review_body': "This is my go-to daily sunblock. It leaves no white cast at all and has a clean, pleasant scent. If you're a makeup wearer, this soaks in quick and provides a nice base for makeup. I've been using this brand for over a year. With daily use, this tube will last you a couple months."}
# {'review_id': 'R1R30FA4RB5P54', 'product_id': 'B000NYL1Z6', 'review_date': '1440979200000', 'customer_id': '2909389', 'vine': 'N', 'star_rating': 4, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 166146615, 'product_title': 'Murad Clarifying Cleanser', 'review_headline': 'Four Stars', 'review_body': 'Good'}
# {'review_id': 'R30IJKCGJBGPJH', 'product_id': 'B001SYWTFG', 'review_date': '1440979200000', 'customer_id': '19397215', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 111742328, 'product_title': 'CoverGirl Queen Collection Perfect Point Plus Eyeliner Black Onyx 200', 'review_headline': 'Good buy', 'review_body': 'Great eyeliner, does run just a little bit at corners at times, but overall, it does keep on your eyes all day long.'}
# {'review_id': 'R18GLJJPVQ1OVH', 'product_id': 'B005F2EVMQ', 'review_date': '1440979200000', 'customer_id': '3195210', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 255803087, 'product_title': 'Bifesta Mandom Eye Makeup Remover, 145ml', 'review_headline': 'Five Stars', 'review_body': 'Best makeup remover！'}
# {'review_id': 'R8TVYIJXLYJT0', 'product_id': 'B00M1SUW7K', 'review_date': '1440979200000', 'customer_id': '52216383', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 246816549, 'product_title': 'Can You Handlebar All-Natural Secondary Moustache Wax : Extra Strength, Firm Hold', 'review_headline': 'Tame the wild mustache', 'review_body': "This is a great product. I'm on my latest stab at a major beard, and I always seem to start growing them during the hottest months. My mustache is going through a particularly awkward phase of growth, and this wax really helps keep it in place, out of the way. I look neater and I can actually eat and drink again without collecting a big mess. If you're going to get this, do yourself a favor and get a good mustache comb."}
# {'review_id': 'R1CJGF6M3PVHEZ', 'product_id': 'B001KYQA1S', 'review_date': '1440979200000', 'customer_id': '10278216', 'vine': 'N', 'star_rating': 1, 'helpful_votes': 0, 'total_votes': 2, 'verified_purchase': 'Y', 'product_parent': 9612905, 'product_title': 'Maybelline Great Lash Washable Mascara, Clear [110], 1 ea', 'review_headline': "but it's like having nothing on them at all", 'review_body': "I thought it would darken the lashes even though it's clear, but it's like having nothing on them at all. Sadly I threw it away."}
# {'review_id': 'R2A30ALEGLMCGN', 'product_id': 'B00SAQ9DZY', 'review_date': '1440979200000', 'customer_id': '24655453', 'vine': 'N', 'star_rating': 4, 'helpful_votes': 1, 'total_votes': 1, 'verified_purchase': 'Y', 'product_parent': 292127037, 'product_title': '12 New, High Quality, Amber 2 ml (5/8 Dram) Glass Bottles, with Orifice Reducer and Black Cap.', 'review_headline': 'Good Product', 'review_body': "These are great for small mixtures for EO's, especially for traveling.  I only gave this 4 stars because of the orifice reducer.  The hole is so small it is hard to get the oil out.  Just needs to be slightly bigger."}
# {'review_id': 'R134GP1Y3EQZ1L', 'product_id': 'B00HFQQ0VU', 'review_date': '1440979200000', 'customer_id': '30788223', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 311309827, 'product_title': 'Waterpik Aquarius Water Flosser', 'review_headline': 'Optimum Oral Health', 'review_body': 'Just got this.  Nice size and very compact.  I am looking forward to the gum massaging.  I wore out my last model.'}
# {'review_id': 'R6CE3SOIUJGP4', 'product_id': 'B00PYL8MAA', 'review_date': '1440979200000', 'customer_id': '11257536', 'vine': 'N', 'star_rating': 4, 'helpful_votes': 1, 'total_votes': 1, 'verified_purchase': 'N', 'product_parent': 390030149, 'product_title': 'Proganix Agave Nectar Plus Silica Curling Cream Plus Defrizzant, 6 Ounce', 'review_headline': 'Love this cream !', 'review_body': 'Wish I had discovered this years ago ! Leaves my curles super defined and soft !!!. I still need to put on gel or spray for it to last though but it is super recommend it!'}
# {'review_id': 'R37CDLQZUPDZVM', 'product_id': 'B00D9NV2D4', 'review_date': '1440979200000', 'customer_id': '29605778', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 794858888, 'product_title': 'Shea Butter', 'review_headline': 'It works so much better than store bought lotion', 'review_body': 'I bought this to make my own lotion. I mixed the shea butter and coconut oil together. It works so much better than store bought lotion! I want to get some raw cocoa butter to mix in with the next batch.'}
# {'review_id': 'R1KH9XCK6GYT26', 'product_id': 'B008Y9M412', 'review_date': '1440979200000', 'customer_id': '41238422', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 874223919, 'product_title': 'Etude House Fresh Cherry Tint # 02 RD301', 'review_headline': 'Five Stars', 'review_body': "The tint is awesome but seller don't even send one sample."}
# {'review_id': 'R3I4BQ6654MQNA', 'product_id': 'B00FWXBLHG', 'review_date': '1440979200000', 'customer_id': '23620123', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 1, 'total_votes': 1, 'verified_purchase': 'Y', 'product_parent': 464001209, 'product_title': "Vintage Lil' Sponge Holder", 'review_headline': 'Great product, fast delivery', 'review_body': "I'm in love with this! It's so unique and fits with my decor beautifully.  Couldn't ask for a better seller.  Received product before date promised."}
# {'review_id': 'R3LUPG356F1D40', 'product_id': 'B003KL8CB0', 'review_date': '1440979200000', 'customer_id': '25564245', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 3, 'total_votes': 3, 'verified_purchase': 'N', 'product_parent': 328680790, 'product_title': 'Jenna Jameson Heartbreaker Perfume parent', 'review_headline': 'Does not smell cheap!', 'review_body': 'I was given this product in exchange for a review. All I can say is wow!!!! I love perfume, and this is a great scent! The notes are a little heavy but i really like it overall. I get headaches easily, but this doesnt seem to do that with me. Does not smell cheap!!! It is a wonderful fragrance for not a lot of money! I love it, you should give it a try!'}
# {'review_id': 'R3HNVRTHL9S2ZB', 'product_id': 'B006R2LNV0', 'review_date': '1440979200000', 'customer_id': '801375', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'N', 'product_parent': 620737389, 'product_title': 'Korean Cosmetics_Isa Knox X2D2 Original Hydra Serum_50ml', 'review_headline': 'Five Stars', 'review_body': 'Magical everybody noticed a skin change right away'}
# {'review_id': 'R5HKL5RD4IUT8', 'product_id': 'B00SMIIR0W', 'review_date': '1440979200000', 'customer_id': '9478730', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 351973146, 'product_title': 'Schick Hydro Silk TrimStyle Moisturizing Razor', 'review_headline': 'Love this Razor/Trimmer', 'review_body': "Works fantastic! The razor leaves my legs really smooth unlike most disposable razors I've used. The razor runs acrossed your skin so smoothly you don't feel like its doing anything. The trimmer is a trimmer it trims, not meant for down to the skin shave but it gets close enough so you can just run the razor through and boom smooth!"}
# {'review_id': 'R37Z8NBTHPR853', 'product_id': 'B003UKKH6O', 'review_date': '1440979200000', 'customer_id': '18418407', 'vine': 'N', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'Y', 'product_parent': 10034795, 'product_title': 'Oral-B Vitality Prowhite Rechargeable Electric Toothbrush 1 Count', 'review_headline': 'Five Stars', 'review_body': 'excellent battery tooth brush'}
# {'review_id': 'RD8F1K5G9W1VX', 'product_id': 'B00PATJU8Y', 'review_date': '1440979200000', 'customer_id': '42644737', 'vine': 'Y', 'star_rating': 3, 'helpful_votes': 0, 'total_votes': 0, 'verified_purchase': 'N', 'product_parent': 379370722, 'product_title': 'TRESemmé PERFECTLY (UN)DONE Hair Spray 7.7 oz', 'review_headline': "Works Okay As A Styling Aid, But Doesn't Give My Straight Hair A Fun Beachy Look", 'review_body': "This Tresemme product is for creating beachy looking hair whether you have curly or straight hair. But I have such straight hair without any real body so the beachy look just isn't a good look for me, unlike in my younger years when I loosely permed my hair and my hair would look great at the beach even after swimming in the ocean half the day. I tried twisting my hair and styling per the instructions for straight hair, and it just didn't look good at all. My hair ended up looking stringy, sloppy and unstyled. To be fair, I don't think any spray on product could give me that awesome beachy look due to my straight hair type.<br /><br />If I spray this Tresemme on my damp hair and blow dry as usual with a round brush, it does adds a little lift, volume and texture to my straight hair. But it's just one more product to add to the routine as it doesn't substitute for my hair gel or any other product, and I still need to finish with my Zero Weight Gel for shaping, hair separation and taming flyaway hairs. This Tresemme may work great for curly or wavy hair, but for my straight hair it doesn't create an attractive beachy look. While it does work okay as a styling aid, it's just one more product to add to my routine that I can live without. It's just okay."}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-12eb173be706> in <cell line: 3>()
#       3 for item in data[:10000]:
#       4     helper = STTM(input_json=item)
# ----> 5     response, mapping = helper.get_transformed_data()
#       6     transformed_data.append(response)
#       7     print(response)
#
# <ipython-input-13-8fa598e0e8e7> in get_transformed_data(self)
#      45                     json_path=mapping_source_data.get("source_field_mapping"),
#      46                     json_data=self.input_json
# ---> 47                 ).get()
#      48
#      49                 """check the data type for source if matches with what we have """
#
# <ipython-input-12-0cd1d4b5f2bc> in get(self)
#       5
#       6     def get(self):
# ----> 7         jsonpath_expression = parse(self.json_path)
#       8         match = jsonpath_expression.find(self.json_data)
#       9         source_data_value = match[0].value
#
# /usr/local/lib/python3.10/dist-packages/jsonpath_ng/parser.py in parse(string)
#      19
#      20 def parse(string):
# ---> 21     return JsonPathParser().parse(string)
#      22
#      23
#
# /usr/local/lib/python3.10/dist-packages/jsonpath_ng/parser.py in parse(self, string, lexer)
#      42     def parse(self, string, lexer = None):
#      43         lexer = lexer or self.lexer_class()
# ---> 44         return self.parse_token_stream(lexer.tokenize(string))
#      45
#      46     def parse_token_stream(self, token_iterator, start_symbol='jsonpath'):
#
# /usr/local/lib/python3.10/dist-packages/jsonpath_ng/parser.py in parse_token_stream(self, token_iterator, start_symbol)
#      57
#      58         # And we regenerate the parse table every time; it doesn't actually take that long!
# ---> 59         new_parser = ply.yacc.yacc(module=self,
#      60                                    debug=self.debug,
#      61                                    tabmodule = parsing_table_module,
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in yacc(method, debug, module, tabmodule, start, check_recursion, optimize, write_tables, debugfile, outputdir, debuglog, errorlog, picklefile)
#    3436         errorlog.debug('Generating %s tables', method)
#    3437
# -> 3438     lr = LRGeneratedTable(grammar, method, debuglog)
#    3439
#    3440     if debug:
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in __init__(self, grammar, method, log)
#    2133         self.grammar.compute_first()
#    2134         self.grammar.compute_follow()
# -> 2135         self.lr_parse_table()
#    2136
#    2137     # Compute the LR(0) closure operation on I, where I is a set of LR(0) items.
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in lr_parse_table(self)
#    2549
#    2550         if self.lr_method == 'LALR':
# -> 2551             self.add_lalr_lookaheads(C)
#    2552
#    2553         # Build the parser table, state by state
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in add_lalr_lookaheads(self, C)
#    2519
#    2520         # Compute lookback/includes relations
# -> 2521         lookd, included = self.compute_lookback_includes(C, trans, nullable)
#    2522
#    2523         # Compute LALR FOLLOW sets
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in compute_lookback_includes(self, C, trans, nullable)
#    2384             includes = []
#    2385             for p in C[state]:
# -> 2386                 if p.name != N:
#    2387                     continue
#    2388
#
# KeyboardInterrupt:

# %%
mapping
# Out:
# {'review_id': 'dimReviewInfo',
#  'product_id': 'dimProduct',
#  'review_date': 'fact',
#  'customer_id': 'fact',
#  'vine': 'fact',
#  'star_rating': 'fact',
#  'helpful_votes': 'fact',
#  'total_votes': 'fact',
#  'verified_purchase': 'fact',
#  'product_parent': 'dimProduct',
#  'product_title': 'dimProduct',
#  'review_headline': 'dimReviewInfo',
#  'review_body': 'dimReviewInfo'}

# %% [markdown]
# ### **Creating 3 seperate tables and printing Fact table**

# %%
# Create separate lists to hold data for each table
dimReviewInfo_data = []
dimProduct_data = []
fact_data = []

# Iterate over each transformed data dictionary
for data in transformed_data:
    # Extract the relevant columns based on the table specified in the mapping
    dimReviewInfo_row = [data[column] for column, table in mapping.items() if table == 'dimReviewInfo']
    dimProduct_row = [data[column] for column, table in mapping.items() if table == 'dimProduct']
    fact_row = [data[column] for column, table in mapping.items() if table == 'fact']

    # Append the rows to the respective tables' data lists
    dimReviewInfo_data.append(dimReviewInfo_row)
    dimProduct_data.append(dimProduct_row)
    fact_data.append(fact_row)

# Create DataFrames for each table
dimReviewInfo_df = pd.DataFrame(dimReviewInfo_data, columns=[column for column, table in mapping.items() if table == 'dimReviewInfo'])
dimProduct_df = pd.DataFrame(dimProduct_data, columns=[column for column, table in mapping.items() if table == 'dimProduct'])
fact_df = pd.DataFrame(fact_data, columns=[column for column, table in mapping.items() if table == 'fact'])

# Add 'review_id' and 'product_id' columns to the fact_data DataFrame
#fact_df['review_id'] = dimReviewInfo_df['review_id']
#fact_df['product_id'] = dimProduct_df['product_id']
fact_df.insert(0, 'review_id', dimReviewInfo_df['review_id'])
fact_df.insert(1, 'product_id', dimProduct_df['product_id'])
# Print the FACT table
fact_df
# Out:
#          review_id  product_id    review_date customer_id vine  star_rating  \
# 0   R3I2DHQBR577SS  B001ANOOOE  1440979200000     1797882    N            5
# 1   R1QNE9NQFJC2Y4  B0016J22EQ  1440979200000    18381298    N            5
# 2   R3LIDG2Q4LJBAO  B00HU6UQAG  1440979200000    19242472    N            5
# 3   R3KSZHPAEVPEAL  B002HWS7RM  1440979200000    19551372    N            5
# 4    RAI2OIG50KZ43  B00SM99KWU  1440979200000    14802407    N            5
# 5   R1R30FA4RB5P54  B000NYL1Z6  1440979200000     2909389    N            4
# 6   R30IJKCGJBGPJH  B001SYWTFG  1440979200000    19397215    N            5
# 7   R18GLJJPVQ1OVH  B005F2EVMQ  1440979200000     3195210    N            5
# 8    R8TVYIJXLYJT0  B00M1SUW7K  1440979200000    52216383    N            5
# 9   R1CJGF6M3PVHEZ  B001KYQA1S  1440979200000    10278216    N            1
# 10  R2A30ALEGLMCGN  B00SAQ9DZY  1440979200000    24655453    N            4
# 11  R134GP1Y3EQZ1L  B00HFQQ0VU  1440979200000    30788223    N            5
# 12   R6CE3SOIUJGP4  B00PYL8MAA  1440979200000    11257536    N            4
# 13  R37CDLQZUPDZVM  B00D9NV2D4  1440979200000    29605778    N            5
# 14  R1KH9XCK6GYT26  B008Y9M412  1440979200000    41238422    N            5
# 15  R3I4BQ6654MQNA  B00FWXBLHG  1440979200000    23620123    N            5
# 16  R3LUPG356F1D40  B003KL8CB0  1440979200000    25564245    N            5
# 17  R3HNVRTHL9S2ZB  B006R2LNV0  1440979200000      801375    N            5
# 18   R5HKL5RD4IUT8  B00SMIIR0W  1440979200000     9478730    N            5
# 19  R37Z8NBTHPR853  B003UKKH6O  1440979200000    18418407    N            5
# 20   RD8F1K5G9W1VX  B00PATJU8Y  1440979200000    42644737    Y            3
#
#     helpful_votes  total_votes verified_purchase
# 0               0            0                 Y
# 1               0            0                 Y
# 2               0            0                 Y
# 3               0            0                 Y
# 4               0            0                 Y
# 5               0            0                 Y
# 6               0            0                 Y
# 7               0            0                 Y
# 8               0            0                 Y
# 9               0            2                 Y
# 10              1            1                 Y
# 11              0            0                 Y
# 12              1            1                 N
# 13              0            0                 Y
# 14              0            0                 Y
# 15              1            1                 Y
# 16              3            3                 N
# 17              0            0                 N
# 18              0            0                 Y
# 19              0            0                 Y
# 20              0            0                 N

# %% [markdown]
# ### **Printing product table**

# %%
print("\ndimProduct_df:")
dimProduct_df
# Out:
# dimProduct_df:
#     product_id  product_parent  \
# 0   B001ANOOOE         2102612
# 1   B0016J22EQ       106393691
# 2   B00HU6UQAG       375449471
# 3   B002HWS7RM       255651889
# 4   B00SM99KWU       116158747
# 5   B000NYL1Z6       166146615
# 6   B001SYWTFG       111742328
# 7   B005F2EVMQ       255803087
# 8   B00M1SUW7K       246816549
# 9   B001KYQA1S         9612905
# 10  B00SAQ9DZY       292127037
# 11  B00HFQQ0VU       311309827
# 12  B00PYL8MAA       390030149
# 13  B00D9NV2D4       794858888
# 14  B008Y9M412       874223919
# 15  B00FWXBLHG       464001209
# 16  B003KL8CB0       328680790
# 17  B006R2LNV0       620737389
# 18  B00SMIIR0W       351973146
# 19  B003UKKH6O        10034795
# 20  B00PATJU8Y       379370722
#
#                                         product_title
# 0   The Naked Bee Vitmin C Moisturizing Sunscreen ...
# 1       Alba Botanica Sunless Tanning Lotion, 4 Ounce
# 2           Elysee Infusion Skin Therapy Elixir, 2oz.
# 3   Diane D722 Color, Perm And Conditioner Process...
# 4   Biore UV Aqua Rich Watery Essence SPF50+/PA+++...
# 5                           Murad Clarifying Cleanser
# 6   CoverGirl Queen Collection Perfect Point Plus ...
# 7            Bifesta Mandom Eye Makeup Remover, 145ml
# 8   Can You Handlebar All-Natural Secondary Mousta...
# 9   Maybelline Great Lash Washable Mascara, Clear ...
# 10  12 New, High Quality, Amber 2 ml (5/8 Dram) Gl...
# 11                    Waterpik Aquarius Water Flosser
# 12  Proganix Agave Nectar Plus Silica Curling Crea...
# 13                                        Shea Butter
# 14           Etude House Fresh Cherry Tint # 02 RD301
# 15                         Vintage Lil' Sponge Holder
# 16          Jenna Jameson Heartbreaker Perfume parent
# 17  Korean Cosmetics_Isa Knox X2D2 Original Hydra ...
# 18     Schick Hydro Silk TrimStyle Moisturizing Razor
# 19  Oral-B Vitality Prowhite Rechargeable Electric...
# 20      TRESemmé PERFECTLY (UN)DONE Hair Spray 7.7 oz

# %% [markdown]
# ### **Printing Review table**

# %%
print("\ndimReviewInfo_df:")
dimReviewInfo_df
# Out:
# dimReviewInfo_df:
#          review_id                                    review_headline  \
# 0   R3I2DHQBR577SS                                         Five Stars
# 1   R1QNE9NQFJC2Y4                          Thank you Alba Bontanica!
# 2   R3LIDG2Q4LJBAO                                         Five Stars
# 3   R3KSZHPAEVPEAL                                         GOOD DEAL!
# 4    RAI2OIG50KZ43  this soaks in quick and provides a nice base f...
# 5   R1R30FA4RB5P54                                         Four Stars
# 6   R30IJKCGJBGPJH                                           Good buy
# 7   R18GLJJPVQ1OVH                                         Five Stars
# 8    R8TVYIJXLYJT0                             Tame the wild mustache
# 9   R1CJGF6M3PVHEZ        but it's like having nothing on them at all
# 10  R2A30ALEGLMCGN                                       Good Product
# 11  R134GP1Y3EQZ1L                                Optimum Oral Health
# 12   R6CE3SOIUJGP4                                  Love this cream !
# 13  R37CDLQZUPDZVM   It works so much better than store bought lotion
# 14  R1KH9XCK6GYT26                                         Five Stars
# 15  R3I4BQ6654MQNA                       Great product, fast delivery
# 16  R3LUPG356F1D40                              Does not smell cheap!
# 17  R3HNVRTHL9S2ZB                                         Five Stars
# 18   R5HKL5RD4IUT8                            Love this Razor/Trimmer
# 19  R37Z8NBTHPR853                                         Five Stars
# 20   RD8F1K5G9W1VX  Works Okay As A Styling Aid, But Doesn't Give ...
#
#                                           review_body
# 0                    Love this, excellent sun block!!
# 1   The great thing about this cream is that it do...
# 2   Great Product, I'm 65 years old and this is al...
# 3   I use them as shower caps & conditioning caps....
# 4   This is my go-to daily sunblock. It leaves no ...
# 5                                                Good
# 6   Great eyeliner, does run just a little bit at ...
# 7                                Best makeup remover！
# 8   This is a great product. I'm on my latest stab...
# 9   I thought it would darken the lashes even thou...
# 10  These are great for small mixtures for EO's, e...
# 11  Just got this.  Nice size and very compact.  I...
# 12  Wish I had discovered this years ago ! Leaves ...
# 13  I bought this to make my own lotion. I mixed t...
# 14  The tint is awesome but seller don't even send...
# 15  I'm in love with this! It's so unique and fits...
# 16  I was given this product in exchange for a rev...
# 17  Magical everybody noticed a skin change right ...
# 18  Works fantastic! The razor leaves my legs real...
# 19                      excellent battery tooth brush
# 20  This Tresemme product is for creating beachy l...

# %% [markdown]
# ### **Export tables to csv file**

# %%
dimReviewInfo_df.to_csv('dimReviewInfo.csv', index=False)
dimProduct_df.to_csv('dimProduct.csv', index=False)
fact_df.to_csv('fact.csv', index=False)

# %% [markdown]
# ### **SQL Queries**

# %% [markdown]
# **1**
# SELECT star_rating, COUNT(*) AS verified_purchase_count
# FROM fact
# WHERE verified_purchase = 'Y'
# GROUP BY star_rating
# ORDER BY star_rating;
#
# **2**
# SELECT DISTINCT verified_purchase, AVG(star_rating)
# over (partition by (verified_purchase)) AS AvgRating
# FROM fact;
#
# **3**
# SELECT DISTINCT verified_purchase, COUNT(*)
# over (partition by verified_purchase) as Counter
# FROM fact
# WHERE helpful_votes>2;
#
# **4**
# SELECT DISTINCT verified_purchase, AVG(star_rating)
# over (partition by (verified_purchase)) AS AvgRating
# FROM fact AS f JOIN dimReviewInfo as dRI
# on f.review_id = dRI.review_id
# WHERE LENGTH(dRI.review_body) > (
#   SELECT AVG(LENGTH(review_body))
#   FROM dimReviewInfo
# );
#
# **5**
# SELECT DISTINCT verified_purchase, AVG(star_rating)
# over (partition by (verified_purchase)) AS AvgRating
# FROM fact
# WHERE helpful_votes>2;
#
# **6**
# SELECT p.product_id, p.product_title, AVG(f.star_rating) AS average_rating
# FROM dimProduct AS p
# INNER JOIN fact AS f ON p.product_id = f.product_id
# WHERE f.verified_purchase = 'Y'
# GROUP BY p.product_id, p.product_title
# HAVING COUNT(*) >= 10  -- Limit to products with at least 10 comments
# ORDER BY average_rating ASC
# LIMIT 10;
#
# **7**
# SELECT DISTINCT verified_purchase, COUNT(*)
# over (partition by verified_purchase) as Counter
# FROM dimReviewInfo AS ri JOIN fact AS f ON ri.review_id = f.review_id
# WHERE LOWER(ri.review_body) LIKE '%love%';
#
# **8**
# SELECT p.product_title,
#        COUNT(*) AS total_comments,
#        ROUND((COUNT(*) FILTER (WHERE f.star_rating > 4) * 100.0 / COUNT(*)), 2) AS percentage_positive
# FROM dimProduct AS p
# JOIN fact AS f ON p.product_id = f.product_id
# GROUP BY p.product_title
# ORDER BY COUNT(*) DESC
# LIMIT 10;
#
# **9**
# SELECT DISTINCT fact.product_id, COUNT(*) over (PARTITION BY fact.product_id) AS Occurrences
# FROM fact
# JOIN dimReviewInfo ON fact.review_id = dimReviewInfo.review_id
# WHERE dimReviewInfo.review_headline LIKE 'great%' and fact.verified_purchase = 'N'
# ORDER BY Occurrences DESC;
#
# **10**
# SELECT f1.customer_id,
#        AVG(f1.star_rating) OVER (PARTITION BY f1.customer_id) AS average_rating,
#        COUNT(f2.customer_id) AS purchase_count
# FROM fact f1
# JOIN fact f2 ON f1.customer_id = f2.customer_id
# WHERE f1.verified_purchase = 'Y'
# GROUP BY f1.customer_id
# order by purchase_count DESC;
